# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1"> ImageNet - Asynchronous 8 workers</h1>
# <h2 style="text-align: center;" markdown="1"> AlexNet, 8 workers, batch size 1024, "1 hour ImageNet" training regime</h2>

# %%
from Outputs.jupyter_graphs import create_graphs, compare_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
from IPython.display import Markdown, display
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
output_notebook()
plots, scores, table = create_graphs(sim_num=54, linear=True)
display(Markdown('<h3>Min Error - {0:.2f}% , Val Error - {1:.2f}% , Mean Error - {2:.2f}%<h3>'.format(scores[0],scores[2], scores[1])))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="677f7a2a-1e96-4ff7-8575-cd8de2d79508">Loading BokehJS ...</span>
#     </div>
# C:\Users\giladiniv\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\models\sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 6400), ('y', 2502400)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <h3>Min Error - 5.66% , Val Error - 5.91% , Mean Error - 5.94%<h3>

# %% [markdown]
# <h3 style="text-align: left;" markdown="1">Parameters</h3>

# %%
print(table)
# Out:
# Number   Name                      Value
# 0        augment                   1
# 1        bar                       1
# 2        baseline                  128
# 3        batch_size                128
# 4        client                    techmonster5
# 5        dataset                   cifar10
# 6        droprate                  0
# 7        epochs                    6400
# 8        fast_im                   0
# 9        gbn                       0
# 10       grad_clip                 1000
# 11       id                        54
# 12       iterations_per_epoch      390
# 13       layers                    28
# 14       lr                        0.1
# 15       model                     wideresnet
# 16       momentum                  0.0
# 17       name                      wideresnet_54
# 18       nesterov                  0
# 19       notes
# 20       optimizer                 asynchronous
# 21       p_time                    0
# 22       regime                    1
# 23       resume
# 24       rho                       2.5
# 25       save                      100
# 26       sim_num                   10
# 27       start_epoch               0
# 28       tau                       1
# 29       weight_decay              0.0005
# 30       widen_factor              2
# 31       workers_num               32

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5bc7dd80-3f89-4a5f-ab36-ced9952debc9"></div>
# </div>

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="421d839e-d8a0-4f20-bcbc-9586d368cc36"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="acbf5944-2b8b-475f-8a79-6c0f2a2dc4aa"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a0313c11-3d9d-4f2a-8613-ee8699cf5118"></div>
# </div>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
show(plots[4])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="244f6f1a-4463-4139-8567-da26ee9a7f1c"></div>
# </div>

# %%
show(plots[5])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="63e0fba4-ccb2-44a1-8ee0-8d16bee9d7e0"></div>
# </div>

# %%
show(plots[6])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7c6f4149-539e-421d-b1af-719168dcfe9d"></div>
# </div>

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Niv Giladi - Technion
# </footer>
