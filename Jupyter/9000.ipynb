# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from jupyter_graphs import create_graphs
plots, score_1, score_2, table = create_graphs(sim_num=9000)
output_notebook()
show(plots[4])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dbb17daf-7880-42c0-bc53-e847de2c692b">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="80c47f6f-76a9-4086-824f-a282c6a49a93"></div>
# </div>
