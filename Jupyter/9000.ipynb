# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from jupyter_graphs import create_graphs
plots, score_1, score_2, table = create_graphs(sim_num=9000)
output_notebook()
show(plots[4])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6253890b-7b22-49b1-b862-9c13ec795d80">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8565c391-daa5-414f-b0e4-c48666e7050c"></div>
# </div>
