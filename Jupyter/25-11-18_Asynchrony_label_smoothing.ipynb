# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1"> Asynchronous SGD - ImageNet</h1>
# <h2 style="text-align: center;" markdown="1"> Label Smoothing Effect</h2>

# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from Outputs.jupyter_graphs import create_graphs, compare_graphs
from IPython.display import Markdown, display
from IPython.core.interactiveshell import InteractiveShell
import warnings
warnings.filterwarnings('ignore')
sim_num = [101, 211,1001,212, 107, 100]
plots, scores = compare_graphs(sim_nums=sim_num, linear=True)
output_notebook()
for sim in zip(sim_num,scores):
    display(Markdown('<h6> #Simulation {:1d} - Min Error {:.2f}% , Mean Error {:.2f}% , Val Error {:.2f}%<h6>'.format(sim[0],sim[1][0],sim[1][1],sim[1][2])))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d6403be3-4ba0-4009-9b35-74b59232f484">Loading BokehJS ...</span>
#     </div>
# <h6> #Simulation 101 - Min Error 25.94% , Mean Error 26.12% , Val Error 26.00%<h6>
# <h6> #Simulation 211 - Min Error 26.20% , Mean Error 26.40% , Val Error 26.20%<h6>
# <h6> #Simulation 1001 - Min Error 23.91% , Mean Error 24.16% , Val Error 24.05%<h6>
# <h6> #Simulation 212 - Min Error 24.32% , Mean Error 24.52% , Val Error 24.37%<h6>
# <h6> #Simulation 107 - Min Error 23.29% , Mean Error 23.50% , Val Error 23.33%<h6>
# <h6> #Simulation 100 - Min Error 23.51% , Mean Error 23.68% , Val Error 23.60%<h6>

# %% [markdown]
# The simulation examines the effect of label smoothing on big batch and asynchronous training.
#
# The number of epochs is the same for all experiments.
#
# (BLUE) Simulation 101 - Asynchronous, 32 worker, 256 batch size + Facebook regime + Label Smoothing
#
# (ORANGE) Simulation 211 - Asynchronous, 32 workers, 256 batch size + Facebook regime
#
# (GREEN) Simulation 1001 - Synchronous, 1 workers, 8192 batch size + Facebook regime + Label Smoothing
#
# (RED) Simulation 212 - Synchronous, 1 workers, 8192 batch size + Facebook regime
#
# (PURPLE) Simulation 107 - Synchronous, 1 workers, 256 batch size + Label Smoothing
#
# (BROWN) Simulation 100 - Synchronous, 1 workers, 256 batch size

# %%
print('Legend - (batchsize, #w, momentum, lr, #sim)')
show(plots[1])
# Out:
# Legend - (batchsize, #w, momentum, lr, #sim)
# <div class="bk-root">
#     <div class="bk-plotdiv" id="301d9305-fcd4-47ca-acd9-b34a0f0afa6d"></div>
# </div>

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b9bfcb6b-e93f-41d1-89b5-a862c6b3fa64"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="319741d1-e5af-469e-a452-08791a9dc39a"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f9a00fd4-55e7-4478-84d3-8ae18064c95c"></div>
# </div>

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Niv Giladi - Technion
# </footer>
