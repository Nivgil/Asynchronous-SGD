# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=2000)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="776405dc-4954-4a05-9a81-4279791dfd3b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR10 - 1 worker, batch size 1280, 6000 epochs
# ## wide resnet - depth 28 , widen factor 2

# %% [markdown]
#       sim_num: 2000
#       epochs: 600
#       batch_size: 1280
#       learning_rate: 0.1 * sqrt(batch_size / 128) / sqrt(workers_num)
#       gradient_clipping: 10
#       momentum: 0.9
#       weight_decay: 0.0005

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="aa3189a3-23fe-4922-88d6-015b1eb74371"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e3dd6201-e4e7-4575-9d65-189d9a7022ba"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c4edf6c4-8a72-4825-bb37-35a86730ae93"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6ef93ef5-9152-44dc-8761-5d4b30a6cef4"></div>
# </div>
