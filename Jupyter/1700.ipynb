# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=1700)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="70e3e39a-5b25-42d4-a28e-87dfaf3b7837">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR10 - Asynchronous with 100 workers
# ## wide resnet - depth 28 , widen factor 2

# %% [markdown]
#       sim_num: 1300
#       epochs: 450
#       batch_size: 128
#       learning_rate: [[0.1, 0.02, 0.004, 0.0008],[1, 200, 300, 380]]
#       gradient_clipping: 5
#       momentum: 0.9
#       weight_decay: 0.0005

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3e4fbf99-6be8-4de1-ba58-fb1039564035"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="49666543-fafd-49e4-a685-19eb33b75744"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="59882406-3395-4cd7-aeb2-73913149aa65"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="753c696f-5faf-411f-bd9b-bb6e3bd134c7"></div>
# </div>
