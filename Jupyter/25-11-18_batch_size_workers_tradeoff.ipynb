# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1"> Asynchronous SGD - CIFAR10</h1>
# <h2 style="text-align: center;" markdown="1"> Batch Size -- Asynchrony Tradeoff</h2>

# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from Outputs.jupyter_graphs import create_graphs, compare_graphs
from IPython.display import Markdown, display
from IPython.core.interactiveshell import InteractiveShell
import warnings
warnings.filterwarnings('ignore')
sim_num = [201, 202, 103,204,206]
plots, scores = compare_graphs(sim_nums=sim_num, linear=True)
output_notebook()
for sim in zip(sim_num,scores):
    display(Markdown('<h6> #Simulation {:1d} - Min Error {:.2f}% , Mean Error {:.2f}% , Val Error {:.2f}%<h6>'.format(sim[0],sim[1][0],sim[1][1],sim[1][2])))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b7acff07-79d8-48f8-bb0d-1b0a04230d55">Loading BokehJS ...</span>
#     </div>
# <h6> #Simulation 201 - Min Error 3.96% , Mean Error 4.05% , Val Error 4.13%<h6>
# <h6> #Simulation 202 - Min Error 3.78% , Mean Error 3.85% , Val Error 3.84%<h6>
# <h6> #Simulation 103 - Min Error 3.52% , Mean Error 3.69% , Val Error 3.67%<h6>
# <h6> #Simulation 204 - Min Error 5.57% , Mean Error 5.67% , Val Error 5.61%<h6>
# <h6> #Simulation 206 - Min Error 9.87% , Mean Error 10.08% , Val Error 10.09%<h6>

# %% [markdown]
# The simulation examines the trade-off between mini batch size and number of workers in a synchrnous / asynchronous setting.
#
# The number of epochs is the same for all experiments.
#
# (BLUE) Simulation 201 - Synchronous, 1 worker, 256 batch size + learning rate adjustment
#
# (ORANGE) Simulation 202 - Synchronous, 16 workers, 16 batch size + learning rate adjustment  (technically it is 1 worker with ghost batch norm of 16)
#
# (GREEN) Simulation 103 - Asynchronous, 16 workers, 16 batch size
#
# (RED) Simulation 204 - Synchronous, 16 workers, 256 batch size + learning rate adjustment + gbn (technically it is 1 worker with batch size of 4096)
#
# (PURPLE) Simulation 206 - Asynchronous, 16 workers, 256 batch size + learning rate adjustment + gbn + momentum 0

# %%
print('Legend - (batchsize, #w, momentum, lr, #sim)')
print('607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[1])
# Out:
# Legend - (batchsize, #w, momentum, lr, #sim)
# 607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="15975abe-9bc6-4000-8fca-0c0c438b6abd"></div>
# </div>

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="2636cd3a-ebe8-47e7-b555-b0b56b9c9556"></div>
# </div>

# %%
print('607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[2])
# Out:
# 607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4012e8da-f018-48ef-89ee-3755eb89d0fb"></div>
# </div>

# %%
print('607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[3])
# Out:
# 607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b3fa6f9f-c812-4d8c-98c7-d9cf5f56cfc7"></div>
# </div>

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Niv Giladi - Technion
# </footer>
