# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=1901)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e5b59cad-2bca-46b0-9505-d87b7537f418">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR10 - Asynchronous with 10 workers
# ## wide resnet - depth 28 , widen factor 2
# ## 1 worker batch size 1280 (orange) VS. 10 workers batch size 128 (green, red & purple)

# %% [markdown]
#       sim_num: 1901
#       epochs: 300
#       batch_size: 128
#       learning_rate: 0.1 * sqrt(batch_size / 128) / sqrt(workers_num)
#       gradient_clipping: 5
#       momentum: 0.9
#       weight_decay: 0.0005

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="0d99a3e7-f6f0-4934-82c8-f6ff15c4a69c"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="705478c7-8a94-4459-8752-9a2e2c5f4555"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7aa63b9c-b782-4ad8-b6a7-1b1219801932"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="877e8ae2-9523-4186-a0a9-76ab8db7dd66"></div>
# </div>
