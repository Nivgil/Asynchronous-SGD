# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=2200)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a806fef8-a26f-4b16-8d7b-b9ec9d082b9e">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR10 - Asynchronous 5 workers
# ## wide resnet - depth 28 , widen factor 2
# ## 5 workers, batch size 128 (blue) vs. 1 worker, batch size 640 (orange)

# %% [markdown]
#       sim_num: 2000
#       epochs: 300
#       batch_size: 128
#       learning_rate: 0.1 * sqrt(batch_size / 128) / sqrt(workers_num)
#       gradient_clipping: 10
#       momentum: 0.9
#       weight_decay: 0.0005
#       nesterov: true
#       droprate: 0
#       augment: true

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b2b6f01f-9d8b-41a8-9738-16a90e16b548"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5cae9ead-2e69-4b07-a185-ddc8828a9557"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ba49c03a-7183-45c9-bad0-8e13ef300fc4"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5084c23a-3796-44df-9b28-2225de06748a"></div>
# </div>
