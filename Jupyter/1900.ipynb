# %%
from jupyter_graphs import create_graphs
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()
plots = create_graphs(sim_num=1900)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c10be82e-1983-49a1-ab92-af1f299a8e73">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # CIFAR10 - Asynchronous with 10 workers
# ## wide resnet - depth 28 , widen factor 2
# ## 1 worker batch size 1280 (orange) VS. 10 workers batch size 128 (green)

# %% [markdown]
#       sim_num: 1900
#       epochs: 450
#       batch_size: 128
#       learning_rate: 0.1 * sqrt(batch_size / 128) / sqrt(workers_num)
#       gradient_clipping: 5
#       momentum: 0.9
#       weight_decay: 0.0005

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1d6f3252-fa8b-42b7-b595-19b3ac5752f3"></div>
# </div>

# %%
show(plots[1])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a97e4ccc-dd85-440c-807e-4a5ea16003a4"></div>
# </div>

# %%
show(plots[2])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="50b5550e-25eb-4dda-9f37-8b425fb40346"></div>
# </div>

# %%
show(plots[3])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d9bb9503-2229-47ea-bd24-157137cb88bf"></div>
# </div>
